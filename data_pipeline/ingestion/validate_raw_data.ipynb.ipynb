# %%
import os
import pandas as pd

# Đường dẫn thư mục raw data
RAW_PATH = "/Users/nthanhdat/Documents/Fpt_Polytechnic/Graduation_Project/data_pipeline/raw_data"

# Danh sách file và nhãn hãng bay tương ứng
file_info = {
    "vietjet_1.csv": "VietJet",
    "vietjet_2.csv": "VietJet",
    "VNairlines_1_1.csv": "VietnamAirlines",
    "VNairlines_2_2.csv": "VietnamAirlines",
    "BambooAirway.csv": "Bamboo"
}

# Load và gắn nhãn hãng
dfs = []
for file_name, airline in file_info.items():
    path = os.path.join(RAW_PATH, file_name)
    df = pd.read_csv(path)
    df['source_file'] = file_name
    df['airline_tag'] = airline
    dfs.append(df)

# Gộp lại thành 1 DataFrame tổng
df_all = pd.concat(dfs, ignore_index=True)
print(f"Tổng số dòng sau khi gộp: {len(df_all)}")
print(f"Các hãng bay trong dữ liệu:", df_all['airline_tag'].value_counts().to_dict())

# ======================== KIỂM TRA DỮ LIỆU ========================

# 1. Kiểm tra thiếu dữ liệu
missing = df_all.isnull().sum()
print("🟡 Các cột bị thiếu dữ liệu:")
print(missing[missing > 0])

# 2. Kiểm tra kiểu dữ liệu
print("\n🟢 Kiểu dữ liệu các cột:")
print(df_all.dtypes)

# 3. Kiểm tra kiểu dữ liệu hỗn hợp
print("\n🔴 Cột có kiểu dữ liệu hỗn hợp:")
for col in df_all.columns:
    if df_all[col].apply(type).nunique() > 1:
        print(f"⚠️  '{col}':", df_all[col].apply(type).value_counts())

# 4. Kiểm tra số âm nếu có cột số
numeric_cols = df_all.select_dtypes(include='number').columns
for col in numeric_cols:
    if (df_all[col] < 0).sum() > 0:
        print(f"\n❌ Cột '{col}' có {(df_all[col] < 0).sum()} giá trị âm")

# 5. Thống kê tổng quát
print("\n📊 Thống kê cơ bản:")
print(df_all.describe(include='all').T)

# 6. Xem 10 dòng đầu
print("\n🔍 10 dòng đầu:")
display(df_all.head(10))
# Out:
# Tổng số dòng sau khi gộp: 2244644
# Các hãng bay trong dữ liệu: {'VietnamAirlines': 1164890, 'VietJet': 1055964, 'Bamboo': 23790}
# 🟡 Các cột bị thiếu dữ liệu:
# Date                          383
# Route                         383
# Flight_ID                     383
# Origin                        383
# Destination                   383
# Fare_Class                    383
# Fare_Code                     383
# Price_VND                     383
# Taxes                         383
# Departure_Time            2220854
# Arrival_Time              2220854
# Booking_Class                 383
# Cabin                         383
# Quota                         383
# Status                        383
# Service_Code                24173
# Fare_Conditions               383
# Operating_Airline_Code        383
# Operating_Airline_Name        383
# dtype: int64
#
# 🟢 Kiểu dữ liệu các cột:
# Source.Name                object
# Date                       object
# Route                      object
# Flight_ID                  object
# Origin                     object
# Destination                object
# Fare_Class                 object
# Fare_Code                  object
# Price_VND                 float64
# Taxes                     float64
# Departure_Time             object
# Arrival_Time               object
# Booking_Class              object
# Cabin                      object
# Quota                     float64
# Status                     object
# Service_Code               object
# Fare_Conditions            object
# Operating_Airline_Code     object
# Operating_Airline_Name     object
# source_file                object
# airline_tag                object
# dtype: object
#
# 🔴 Cột có kiểu dữ liệu hỗn hợp:
# ⚠️  'Date': Date
# <class 'str'>      2244261
# <class 'float'>        383
# Name: count, dtype: int64
# ⚠️  'Route': Route
# <class 'str'>      2244261
# <class 'float'>        383
# Name: count, dtype: int64
# ⚠️  'Flight_ID': Flight_ID
# <class 'str'>      2244261
# <class 'float'>        383
# Name: count, dtype: int64
# ⚠️  'Origin': Origin
# <class 'str'>      2244261
# <class 'float'>        383
# Name: count, dtype: int64
# ⚠️  'Destination': Destination
# <class 'str'>      2244261
# <class 'float'>        383
# Name: count, dtype: int64
# ⚠️  'Fare_Class': Fare_Class
# <class 'str'>      2244261
# <class 'float'>        383
# Name: count, dtype: int64
# ⚠️  'Fare_Code': Fare_Code
# <class 'str'>      2244261
# <class 'float'>        383
# Name: count, dtype: int64
# ⚠️  'Departure_Time': Departure_Time
# <class 'float'>    2220854
# <class 'str'>        23790
# Name: count, dtype: int64
# ⚠️  'Arrival_Time': Arrival_Time
# <class 'float'>    2220854
# <class 'str'>        23790
# Name: count, dtype: int64
# ⚠️  'Booking_Class': Booking_Class
# <class 'str'>      2244261
# <class 'float'>        383
# Name: count, dtype: int64
# ⚠️  'Cabin': Cabin
# <class 'str'>      2244261
# <class 'float'>        383
# Name: count, dtype: int64
# ⚠️  'Status': Status
# <class 'str'>      2244261
# <class 'float'>        383
# Name: count, dtype: int64
# ⚠️  'Service_Code': Service_Code
# <class 'str'>      2220471
# <class 'float'>      24173
# Name: count, dtype: int64
# ⚠️  'Fare_Conditions': Fare_Conditions
# <class 'str'>      2244261
# <class 'float'>        383
# Name: count, dtype: int64
# ⚠️  'Operating_Airline_Code': Operating_Airline_Code
# <class 'str'>      2244261
# <class 'float'>        383
# Name: count, dtype: int64
# ⚠️  'Operating_Airline_Name': Operating_Airline_Name
# <class 'str'>      2244261
# <class 'float'>        383
# Name: count, dtype: int64
#
# 📊 Thống kê cơ bản:
#                             count  unique                                top  \
# Source.Name               2244644      86      CXR-HAN_01-06-25_31-12-25.csv
# Date                      2244261     545                          8/13/2025
# Route                     2244261      42                            CXR_HAN
# Flight_ID                 2244261  116725  SEG-VN1341-CXRSGN-2025-06-14-0840
# Origin                    2244261       9                                DAD
# Destination               2244261       9                                DAD
# Fare_Class                2244261      34                                BF1
# Fare_Code                 2244261      95                               JVNW
# Price_VND               2244261.0     NaN                                NaN
# Taxes                   2244261.0     NaN                                NaN
# Departure_Time              23790   10195                    8/24/2025 22:40
# Arrival_Time                23790   13108                      6/8/2025 1:15
# Booking_Class             2244261      23                                  J
# Cabin                     2244261       3                                eco
# Quota                   2244261.0     NaN                                NaN
# Status                    2244261       1                                 HK
# Service_Code              2220471      21                        FBA4-C0FMC2
# Fare_Conditions           2244261      22                     PEN4,PEN5,PEN6
# Operating_Airline_Code    2244261       3                                 VN
# Operating_Airline_Name    2244261       3                   VietNam Airlines
# source_file               2244644       5                 VNairlines_1_1.csv
# airline_tag               2244644       3                    VietnamAirlines
#
#                            freq           mean             std       min  \
# Source.Name              139722            NaN             NaN       NaN
# Date                       9987            NaN             NaN       NaN
# Route                    180380            NaN             NaN       NaN
# Flight_ID                   198            NaN             NaN       NaN
# Origin                   497428            NaN             NaN       NaN
# Destination              536669            NaN             NaN       NaN
# Fare_Class               426164            NaN             NaN       NaN
# Fare_Code                275781            NaN             NaN       NaN
# Price_VND                   NaN  4755219.99912  3027892.059517  441335.0
# Taxes                       NaN  983491.259443   451671.381433  244784.0
# Departure_Time               20            NaN             NaN       NaN
# Arrival_Time                 12            NaN             NaN       NaN
# Booking_Class            293801            NaN             NaN       NaN
# Cabin                    901965            NaN             NaN       NaN
# Quota                       NaN       8.101097        1.909162       1.0
# Status                  2244261            NaN             NaN       NaN
# Service_Code             576261            NaN             NaN       NaN
# Fare_Conditions          405005            NaN             NaN       NaN
# Operating_Airline_Code  1164507            NaN             NaN       NaN
# Operating_Airline_Name  1164507            NaN             NaN       NaN
# source_file              687680            NaN             NaN       NaN
# airline_tag             1164890            NaN             NaN       NaN
#
#                               25%        50%        75%         max
# Source.Name                   NaN        NaN        NaN         NaN
# Date                          NaN        NaN        NaN         NaN
# Route                         NaN        NaN        NaN         NaN
# Flight_ID                     NaN        NaN        NaN         NaN
# Origin                        NaN        NaN        NaN         NaN
# Destination                   NaN        NaN        NaN         NaN
# Fare_Class                    NaN        NaN        NaN         NaN
# Fare_Code                     NaN        NaN        NaN         NaN
# Price_VND               2499000.0  3957948.0  6178000.0  15921000.0
# Taxes                    630651.0   812000.0  1377000.0   2123000.0
# Departure_Time                NaN        NaN        NaN         NaN
# Arrival_Time                  NaN        NaN        NaN         NaN
# Booking_Class                 NaN        NaN        NaN         NaN
# Cabin                         NaN        NaN        NaN         NaN
# Quota                         9.0        9.0        9.0         9.0
# Status                        NaN        NaN        NaN         NaN
# Service_Code                  NaN        NaN        NaN         NaN
# Fare_Conditions               NaN        NaN        NaN         NaN
# Operating_Airline_Code        NaN        NaN        NaN         NaN
# Operating_Airline_Name        NaN        NaN        NaN         NaN
# source_file                   NaN        NaN        NaN         NaN
# airline_tag                   NaN        NaN        NaN         NaN
#
# 🔍 10 dòng đầu:
#                      Source.Name       Date    Route  \
# 0  DLI-DAD_01-06-25_31-12-25.csv  6/13/2025  DLI_DAD
# 1  DLI-DAD_01-06-25_31-12-25.csv  6/13/2025  DLI_DAD
# 2  DLI-DAD_01-06-25_31-12-25.csv  6/13/2025  DLI_DAD
# 3  DLI-DAD_01-06-25_31-12-25.csv  6/13/2025  DLI_DAD
# 4  DLI-DAD_01-06-25_31-12-25.csv  6/13/2025  DLI_DAD
# 5  DLI-DAD_01-06-25_31-12-25.csv  6/13/2025  DLI_DAD
# 6  DLI-DAD_01-06-25_31-12-25.csv  6/13/2025  DLI_DAD
# 7  DLI-DAD_01-06-25_31-12-25.csv  6/13/2025  DLI_DAD
# 8  DLI-DAD_01-06-25_31-12-25.csv  6/13/2025  DLI_DAD
# 9  DLI-DAD_01-06-25_31-12-25.csv  6/13/2025  DLI_DAD
#
#                          Flight_ID Origin Destination Fare_Class Fare_Code  \
# 0  SEG-VJ358-DLIDAD-2025-1-01-1450    DLI         DAD        EL1   QPXVNWS
# 1  SEG-VJ566-DLIDAD-2025-1-01-1450    DLI         DAD        EC1     ZVNWP
# 2  SEG-VJ955-DLIDAD-2025-1-01-1450    DLI         DAD        EF1     ZVNWP
# 3  SEG-VJ905-DLIDAD-2025-1-01-1450    DLI         DAD        DC1     ZVNWP
# 4  SEG-VJ446-DLIDAD-2025-1-01-1450    DLI         DAD        DF1     ZVNWP
# 5  SEG-VJ272-DLIDAD-2025-1-01-1450    DLI         DAD        BC1     IVNWP
# 6  SEG-VJ013-DLIDAD-2025-1-01-1450    DLI         DAD        BF1     CVNWP
# 7  SEG-VJ086-DLIDAD-2025-1-01-1450    DLI         DAD        EL1     CVNWP
# 8  SEG-VJ336-DLIDAD-2025-1-01-1450    DLI         DAD        EC1     CVNWP
# 9  SEG-VJ833-DLIDAD-2025-1-01-1450    DLI         DAD        EF1     CVNWP
#
#    Price_VND     Taxes  ... Booking_Class       Cabin Quota Status  \
# 0  2118103.0  651845.0  ...             Z  ecoPremium   2.0     HK
# 1  2197289.0  657613.0  ...             Z  ecoPremium   2.0     HK
# 2  2446910.0  676492.0  ...             Z  ecoPremium   2.0     HK
# 3  2530291.0  682261.0  ...             Z  ecoPremium   2.0     HK
# 4  2813474.0  703237.0  ...             Z  ecoPremium   2.0     HK
# 5  3535066.0  756727.0  ...             I    business   8.0     HK
# 6  4327979.0  815461.0  ...             C    business   9.0     HK
# 7  2809803.0  703237.0  ...             T         eco   9.0     HK
# 8  3081974.0  723165.0  ...             L         eco   9.0     HK
# 9  3214126.0  733129.0  ...             M         eco   9.0     HK
#
#    Service_Code    Fare_Conditions Operating_Airline_Code  \
# 0   FBA4-C0FMC2  PEN19,PEN20,PEN21                     VJ
# 1   FBA4-C0FMC2  PEN16,PEN17,PEN18                     VJ
# 2   FBA4-C0FMC2  PEN22,PEN23,PEN24                     VJ
# 3   FBA4-C0FMC2  PEN28,PEN29,PEN30                     VJ
# 4   FBA4-C0FMC2  PEN22,PEN23,PEN24                     VJ
# 5   FBA4-C0FMC2  PEN43,PEN44,PEN45                     VJ
# 6   FBA4-C0FMC2  PEN52,PEN53,PEN54                     VJ
# 7   FBA3-C0GOC1  PEN31,PEN32,PEN33                     VJ
# 8   FBA3-C0GOC1  PEN13,PEN14,PEN15                     VJ
# 9   FBA3-C0GOC1  PEN34,PEN35,PEN36                     VJ
#
#   Operating_Airline_Name    source_file airline_tag
# 0            Vietjet Air  vietjet_1.csv     VietJet
# 1            Vietjet Air  vietjet_1.csv     VietJet
# 2            Vietjet Air  vietjet_1.csv     VietJet
# 3            Vietjet Air  vietjet_1.csv     VietJet
# 4            Vietjet Air  vietjet_1.csv     VietJet
# 5            Vietjet Air  vietjet_1.csv     VietJet
# 6            Vietjet Air  vietjet_1.csv     VietJet
# 7            Vietjet Air  vietjet_1.csv     VietJet
# 8            Vietjet Air  vietjet_1.csv     VietJet
# 9            Vietjet Air  vietjet_1.csv     VietJet
#
# [10 rows x 22 columns]
