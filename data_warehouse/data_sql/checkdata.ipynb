# %%
import pandas as pd

# %%
link_path = '/Users/nthanhdat/Documents/Fpt_Polytechnic/Graduation_Project/data_warehouse/data_sql/data_sql.csv'
df = pd.read_csv(link_path)
# Out:
# /var/folders/hr/83trl0sd2gx6mcrqtr07jxx40000gn/T/ipykernel_43869/3754328151.py:2: DtypeWarning: Columns (13,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(link_path)

# %%
df.head(10)
# Out:
#    flight_id        date    route               original_flight_id origin  \
# 0          0  2025-06-13  DLI_DAD  SEG-VJ568-DLIDAD-2025-1-01-1450    DLI
# 1          1  2025-06-13  DLI_DAD  SEG-VJ886-DLIDAD-2025-1-01-1450    DLI
# 2          2  2025-06-13  DLI_DAD  SEG-VJ430-DLIDAD-2025-1-01-1450    DLI
# 3          3  2025-06-13  DLI_DAD  SEG-VJ180-DLIDAD-2025-1-01-1450    DLI
# 4          4  2025-06-13  DLI_DAD  SEG-VJ376-DLIDAD-2025-1-01-1450    DLI
# 5          5  2025-06-13  DLI_DAD  SEG-VJ256-DLIDAD-2025-1-01-1450    DLI
# 6          6  2025-06-13  DLI_DAD  SEG-VJ465-DLIDAD-2025-1-01-1450    DLI
# 7          7  2025-06-13  DLI_DAD  SEG-VJ966-DLIDAD-2025-1-01-1450    DLI
# 8          8  2025-06-13  DLI_DAD  SEG-VJ874-DLIDAD-2025-1-01-1450    DLI
# 9          9  2025-06-13  DLI_DAD  SEG-VJ006-DLIDAD-2025-1-01-1450    DLI
#
#   destination fare_class fare_code     price_vnd          taxes  ...   day  \
# 0         DAD        EL1   QPXVNWS  1.860040e+06  572426.357322  ...  13.0
# ...
